# %%
name=input("enter your name : ")
age=int(input("enter your age: "))
new_AGE= age+4
print("Hey", name, "you will be", new_AGE, "years old in 2030!")
# Out:
# Hey virat kholi  you will be 37 years old in 2030!

# %%
bill=float(input("enter bil amount : "))
Total_people=int(input("enter number of people : "))
share=bill/Total_people
print("Total Bill:" ,bill, "Each person pays:" ,share,)
# Out:
# Total Bill: 1230.5 Each person pays: 246.1

# %%
item_name = "Laptop"      
quantity = 2             
price = 499.99          
in_stock = True           


print(f"Item:", item_name, ", Qty:", quantity, ", Price:", price, ", Available:", in_stock)


total_cost = quantity * price

print("Total Cost:", total_cost)
# Out:
# Item: Laptop , Qty: 2 , Price: 499.99 , Available: True
# Total Cost: 999.98
